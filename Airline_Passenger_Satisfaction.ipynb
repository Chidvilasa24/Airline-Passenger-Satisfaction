# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Airline_Passenger_Satisfaction.csv')
df
# Out:
#         Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 0                0   70172  ...                     18.0  neutral or dissatisfied
# 1                1    5047  ...                      6.0  neutral or dissatisfied
# 2                2  110028  ...                      0.0                satisfied
# 3                3   24026  ...                      9.0  neutral or dissatisfied
# 4                4  119299  ...                      0.0                satisfied
# ...            ...     ...  ...                      ...                      ...
# 103899      103899   94171  ...                      0.0  neutral or dissatisfied
# 103900      103900   73097  ...                      0.0                satisfied
# 103901      103901   68825  ...                     14.0  neutral or dissatisfied
# 103902      103902   54173  ...                      0.0  neutral or dissatisfied
# ...

# %%
df.shape
# Out:
# (103904, 25)

# %% [markdown]
# ####**Basic Commands**

# %%
df.head()
# Out:
#    Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 0           0   70172  ...                     18.0  neutral or dissatisfied
# 1           1    5047  ...                      6.0  neutral or dissatisfied
# 2           2  110028  ...                      0.0                satisfied
# 3           3   24026  ...                      9.0  neutral or dissatisfied
# 4           4  119299  ...                      0.0                satisfied
#
# [5 rows x 25 columns]

# %%
df.tail(2)
# Out:
#         Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 103902      103902  54173  ...                      0.0  neutral or dissatisfied
# 103903      103903  62567  ...                      0.0  neutral or dissatisfied
#
# [2 rows x 25 columns]

# %%
df.sample(3)
# Out:
#        Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 78750       78750  57130  ...                     13.0                satisfied
# 53995       53995  85334  ...                      0.0                satisfied
# 7692         7692  22103  ...                      2.0  neutral or dissatisfied
#
# [3 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  ...  Arrival Delay in Minutes
# count  103904.000000  ...             103594.000000
# mean    51951.500000  ...                 15.178678
# std     29994.645522  ...                 38.698682
# min         0.000000  ...                  0.000000
# 25%     25975.750000  ...                  0.000000
# 50%     51951.500000  ...                  0.000000
# 75%     77927.250000  ...                 13.000000
# max    103903.000000  ...               1584.000000
#
# [8 rows x 20 columns]

# %%
df.describe(include='all')
# Out:
#            Unnamed: 0  ...             satisfaction
# count   103904.000000  ...                   103904
# unique            NaN  ...                        2
# top               NaN  ...  neutral or dissatisfied
# freq              NaN  ...                    58879
# mean     51951.500000  ...                      NaN
# std      29994.645522  ...                      NaN
# min          0.000000  ...                      NaN
# 25%      25975.750000  ...                      NaN
# 50%      51951.500000  ...                      NaN
# 75%      77927.250000  ...                      NaN
# max     103903.000000  ...                      NaN
#
# [11 rows x 25 columns]

# %% [markdown]
# ### **PREPROCESSING**

# %% [markdown]
# ####**Handling Missing Values**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 310

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# ...

# %%
df['Class'] = df['Class'].fillna(df['Class'].mode()[0])

# %%
df['Flight Distance'] = df['Flight Distance'].fillna(df['Flight Distance'].mean())
df['Inflight wifi service'] = df['Inflight wifi service'].fillna(df['Inflight wifi service'].mean())
df['Departure/Arrival time convenient'] = df['Departure/Arrival time convenient'].fillna(df['Departure/Arrival time convenient'].mean())
df['Ease of Online booking'] = df['Ease of Online booking'].fillna(df['Ease of Online booking'].mean())
df['Gate location'] = df['Gate location'].fillna(df['Gate location'].mean())
df['Food and drink'] = df['Food and drink'].fillna(df['Food and drink'].mean())
df['Online boarding'] = df['Online boarding'].fillna(df['Online boarding'].mean())

# %%
df['Seat comfort'] = df['Seat comfort'].fillna(df['Seat comfort'].median())
df['Inflight entertainment'] = df['Inflight entertainment'].fillna(df['Inflight entertainment'].median())
df['On-board service'] = df['On-board service'].fillna(df['On-board service'].median())
df['Leg room service'] = df['Leg room service'].fillna(df['Leg room service'].median())
df['Baggage handling'] = df['Baggage handling'].fillna(df['Baggage handling'].median())
df['Checkin service'] = df['Checkin service'].fillna(df['Checkin service'].median())
df['Inflight service'] = df['Inflight service'].fillna(df['Inflight service'].median())

# %%
df['Cleanliness'] = df['Cleanliness'].fillna(df['Cleanliness'].mode()[0])
df['Departure Delay in Minutes'] = df['Departure Delay in Minutes'].fillna(df['Departure Delay in Minutes'].mode()[0])
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mode()[0])

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ####**Cleaning**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *So now there are no null values and duplicates in our dataset.*

# %% [markdown]
# ####**Groupby and Sorting**

# %%
df1 = df.copy()
df1.head(2)
# Out:
#    Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0           0  70172  ...                     18.0  neutral or dissatisfied
# 1           1   5047  ...                      6.0  neutral or dissatisfied
#
# [2 rows x 25 columns]

# %%
df2 = df1.sort_values('Age', ascending=False)
df2
# Out:
#        Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 2023         2023    8581  ...                      7.0  neutral or dissatisfied
# 64998       64998   32709  ...                      5.0  neutral or dissatisfied
# 85416       85416   92780  ...                      0.0                satisfied
# 28863       28863   37233  ...                     76.0                satisfied
# 35919       35919  125071  ...                      0.0  neutral or dissatisfied
# ...           ...     ...  ...                      ...                      ...
# 22282       22282   24503  ...                      0.0  neutral or dissatisfied
# 41967       41967   95182  ...                      0.0  neutral or dissatisfied
# 10307       10307   82631  ...                      0.0  neutral or dissatisfied
# 66173       66173  100193  ...                      4.0  neutral or dissatisfied
# 40043       40043  111902  ...                     15.0  neutral or dissatisfied
#
# ...

# %%
df3 = df1.sort_values(['Arrival Delay in Minutes', 'Departure Delay in Minutes'], ascending = [True, True])
df3
# Out:
#        Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 2               2  110028  ...                      0.0                satisfied
# 4               4  119299  ...                      0.0                satisfied
# 5               5  111157  ...                      0.0  neutral or dissatisfied
# 8               8   79485  ...                      0.0  neutral or dissatisfied
# 9               9   65725  ...                      0.0  neutral or dissatisfied
# ...           ...     ...  ...                      ...                      ...
# 61287       61287    4376  ...                    952.0  neutral or dissatisfied
# 72206       72206   78300  ...                    970.0  neutral or dissatisfied
# 61310       61310    4903  ...                   1011.0                satisfied
# 6744         6744   69661  ...                   1280.0                satisfied
# 83741       83741   73471  ...                   1584.0  neutral or dissatisfied
#
# ...

# %%
df4 = df1.sort_values(['Arrival Delay in Minutes', 'Departure Delay in Minutes'], ascending = [True, False])
df4
# Out:
#         Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 71557        71557  29974  ...                      0.0  neutral or dissatisfied
# 83395        83395  33367  ...                      0.0  neutral or dissatisfied
# 94724        94724  38176  ...                      0.0  neutral or dissatisfied
# 83880        83880   9177  ...                      0.0  neutral or dissatisfied
# 102067      102067  36729  ...                      0.0  neutral or dissatisfied
# ...            ...    ...  ...                      ...                      ...
# 61287        61287   4376  ...                    952.0  neutral or dissatisfied
# 72206        72206  78300  ...                    970.0  neutral or dissatisfied
# 61310        61310   4903  ...                   1011.0                satisfied
# 6744          6744  69661  ...                   1280.0                satisfied
# 83741        83741  73471  ...                   1584.0  neutral or dissatisfied
#
# ...

# %%
df1.nlargest(8, 'Flight Distance')
# Out:
#        Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 2847         2847  31870  ...                      0.0                satisfied
# 18434       18434  31876  ...                      0.0                satisfied
# 19755       19755  31871  ...                      0.0                satisfied
# 33094       33094  31878  ...                      0.0  neutral or dissatisfied
# 46848       46848  31812  ...                      0.0                satisfied
# 64631       64631  31875  ...                      0.0                satisfied
# 64791       64791  31873  ...                      0.0                satisfied
# 67767       67767  31880  ...                      0.0                satisfied
#
# [8 rows x 25 columns]

# %%
df1.nlargest(7, 'Arrival Delay in Minutes', keep='last')
# Out:
#        Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 83741       83741  73471  ...                   1584.0  neutral or dissatisfied
# 6744         6744  69661  ...                   1280.0                satisfied
# 61310       61310   4903  ...                   1011.0                satisfied
# 72206       72206  78300  ...                    970.0  neutral or dissatisfied
# 61287       61287   4376  ...                    952.0  neutral or dissatisfied
# 61528       61528  83676  ...                    924.0  neutral or dissatisfied
# 80182       80182   8345  ...                    920.0                satisfied
#
# [7 rows x 25 columns]

# %%
df2 = df1.groupby('Gender')

# %%
df2.first()
# Out:
#         Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# Gender                      ...
# Female           2  110028  ...                      0.0                satisfied
# Male             0   70172  ...                     18.0  neutral or dissatisfied
#
# [2 rows x 24 columns]

# %%
df3 = df1.groupby(['Gender', 'Customer Type'])

# %%
df4 = df1.groupby(['Gender', 'Customer Type']).count()
df4
# Out:
#                           Unnamed: 0  ...  satisfaction
# Gender Customer Type                  ...
# Female Loyal Customer          42458  ...         42458
#        disloyal Customer       10269  ...         10269
# Male   Loyal Customer          42465  ...         42465
#        disloyal Customer        8712  ...          8712
#
# [4 rows x 23 columns]

# %%
df5 = df1.groupby(['Gender', 'Class']).count()
df5
# Out:
#                  Unnamed: 0     id  ...  Arrival Delay in Minutes  satisfaction
# Gender Class                        ...
# Female Business       24927  24927  ...                     24927         24927
#        Eco            23858  23858  ...                     23858         23858
#        Eco Plus        3942   3942  ...                      3942          3942
# Male   Business       24738  24738  ...                     24738         24738
#        Eco            22887  22887  ...                     22887         22887
#        Eco Plus        3552   3552  ...                      3552          3552
#
# [6 rows x 23 columns]

# %%
df6 = df1.groupby(['Type of Travel','Class']).count()
df6
# Out:
#                           Unnamed: 0  ...  satisfaction
# Type of Travel  Class                 ...
# Business travel Business       47508  ...         47508
#                 Eco            20257  ...         20257
#                 Eco Plus        3890  ...          3890
# Personal Travel Business        2157  ...          2157
#                 Eco            26488  ...         26488
#                 Eco Plus        3604  ...          3604
#
# [6 rows x 23 columns]

# %% [markdown]
# ####**CrossTab**

# %%
pd.crosstab(df['Class'],df['Cleanliness'])
# Out:
# Cleanliness  0     1     2      3      4      5
# Class
# Business     4  4730  5559  12686  14621  12065
# Eco          3  7449  9141  10202  10799   9151
# Eco Plus     5  1139  1432   1686   1759   1473

# %%
pd.crosstab(df['Class'],df['Seat comfort'])
# Out:
# Seat comfort  0     1     2     3      4      5
# Class
# Business      1  3495  4861  7243  18488  15577
# Eco           0  7480  8697  9813  11363   9392
# Eco Plus      0  1100  1339  1640   1914   1501

# %%
pd.crosstab(df['satisfaction'],df['Food and drink'])
# Out:
# Food and drink            0      1      2      3      4      5
# satisfaction
# neutral or dissatisfied  57  10269  13458  13461  11571  10063
# satisfied                50   2568   8530   8839  12788  12250

# %%
pd.crosstab(df['Type of Travel'],df['satisfaction'])
# Out:
# satisfaction     neutral or dissatisfied  satisfied
# Type of Travel
# Business travel                    29909      41746
# Personal Travel                    28970       3279

# %% [markdown]
# ###**VISUALIZATION**

# %%
df = pd.read_csv('/content/drive/MyDrive/airline_passenger_satisfaction.csv')
df.head()
# Out:
#        id  Gender  ... Arrival Delay in Minutes             satisfaction
# 0   70172    Male  ...                     18.0  neutral or dissatisfied
# 1    5047    Male  ...                      6.0  neutral or dissatisfied
# 2  110028  Female  ...                      0.0                satisfied
# 3   24026  Female  ...                      9.0  neutral or dissatisfied
# 4  119299    Male  ...                      0.0                satisfied
#
# [5 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(11,8))
sns.violinplot(df['Gender'],df['Age'],hue=df['Class']).set_title("Gender V/S Age")
plt.legend(bbox_to_anchor=(1.2,1))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Inference:**

# %% [markdown]
# From this we can say that for Eco Plus class Age of Female is distributed more among different values whereas for Business class Age of Male is distributed more and for Eco class Female is distributed more.

# %%
plt.figure(figsize=(11,8))
plt.bar(df['Seat comfort'],df['Flight Distance'],0.7)
plt.xlabel('Seat Comfort')
plt.ylabel('Flight Distance')
plt.title('How comfortable seats are in Long-distanced flights??')
# Out:
# Text(0.5, 1.0, 'How comfortable seats are in Long-distanced flights??')

# %% [markdown]
# **Inference:**

# %% [markdown]
# From this we can say that, most of the short and average distanced flights are rated 3 in terms of Seat Comfort there are also two instances where Seat comfort is rated 4 and 2 for maximum distanced flights in our dataset.

# %%
plt.figure(figsize=(11,8))
sns.scatterplot(df['Age'],df['Flight Distance'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Inference:**

# %% [markdown]
# We can say that without taking Age consideration, flights of different distances are chosen by people so there is no relation between Age and Flight Distance.

# %%
plt.figure(figsize=(11,8))
sns.scatterplot(df['Arrival Delay in Minutes'],df['Departure Delay in Minutes'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Inference:**

# %% [markdown]
# From this we can say that mostly the Arrival and Departure delay is in range of 0 to 25 minutes. Also, Arrival Delay and Departure Delay are directly proportional i.e., if arrival delay increases then the Departure Delay also increases.

# %%
plt.figure(figsize=(11,8))
sns.boxplot(df['Inflight wifi service'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Inference:**  There are not outliers in "Inflight wifi service" column.

# %%
plt.figure(figsize=(11,8))
sns.boxplot(df['Flight Distance'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Inference:** There are 3/4 outliers in "Flight Distance" column.

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,7))
sns.swarmplot(df['Departure/Arrival time convenient'],df['Flight Distance'],hue=df['Customer Type']).set_title('Are Long-distance flights time-convenient??')
plt.legend(bbox_to_anchor=(1.3,1))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Inference:**

# %% [markdown]
# Most of the loyal customers have given the rating of time convenience to be 4 for Short distance flights and 5 for average distance flight and disloyal customers have mostly given rating as 1 or short distanced flights.

# %%
plt.figure(figsize=(11,8))
sns.pairplot(df,vars=['On-board service','Ease of Online booking'])

# %% [markdown]
# **Inference:**

# %% [markdown]
# Ratings of On-board service and Easy of Online booking are very distant there are not at all correlated.

# %%
plt.figure(figsize=(25,8))
sns.set(rc={'xtick.labelsize':6,'ytick.labelsize':6,'axes.labelsize':10})
sns.set_style('white')
sns.catplot(x='Leg room service', y='Food and drink', col='satisfaction', data=df, kind='strip')

# %% [markdown]
# **Inference:**

# %% [markdown]
# Leg room Service rating and Food and drink rating in neutral/ dissatisfied i evenly distributed i.e., if Leg room service rating is i, then all ratings from 1 to i is there for Food and drink.

# %% [markdown]
# ###**EDA (Exploratory Data Analytics)**

# %%
df['Class'].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
ecoPlus = df[df['Class']=='Eco Plus']
business = df[df['Class']=='Business']
eco = df[df['Class']=='Eco']

# %%
print("EcoPlus:", ecoPlus.shape)
print("Business: ", business.shape)
print("Eco: ",eco.shape)
# Out:
# EcoPlus: (7494, 25)
# Business:  (49665, 25)
# Eco:  (46745, 25)

# %%
print("Average age of people who chose \"EcoPlus\" class: ", ecoPlus['Age'].mean())
print("Average age of people who chose \"Business\" class: ", business['Age'].mean())
print("Average age of people who chose \"Eco\" class: ", eco['Age'].mean())
# Out:
# Average age of people who chose "EcoPlus" class:  38.65452361889512
# Average age of people who chose "Business" class:  41.574327997583815
# Average age of people who chose "Eco" class:  37.16425286126859

# %%
eco_above50 = eco[eco['Age']>50]

# %%
print("Average age of people having age above 50 in \"Eco\" class is:", eco_above50['Age'].mean())
# Out:
# Average age of people having age above 50 in "Eco" class is: 59.829406706792774

# %%
male = df[df['Gender'] == 'Male']
female = df[df['Gender'] == 'Female']
print("Male: ", male.shape)
print("Female: ", female.shape)
# Out:
# Male:  (51177, 25)
# Female:  (52727, 25)

# %%
print("                                                  Mean                Variance             Standard deviation")
print("Statistics of Flight Distance chosen by Male:   ",male['Flight Distance'].mean()," ", male['Flight Distance'].var()," ",male['Flight Distance'].std())
print("Statistics of Flight Distance chosen by Female: ",female['Flight Distance'].mean()," ", female['Flight Distance'].var()," ",female['Flight Distance'].std())
# Out:
#                                                   Mean                Variance             Standard deviation
# Statistics of Flight Distance chosen by Male:    1195.346620552201   996659.8987865029   998.3285525249205
# Statistics of Flight Distance chosen by Female:  1183.7235192595824   991967.110637363   995.9754568448778

# %%
satisfied = df[df['satisfaction'] == 'satisfied']
dissatisfied_neutral = df[df['satisfaction'] == 'neutral or dissatisfied']

# %%
print("Type of Travel most people are satisfied with: ", satisfied['Type of Travel'].mode()[0])
# Out:
# Type of Travel most people are satisfied with:  Business travel

# %%
print("Type of Customer who were mostly dissatisfied or neutral: ", dissatisfied_neutral['Customer Type'].mode()[0])
# Out:
# Type of Customer who were mostly dissatisfied or neutral:  Loyal Customer

# %%
print("Rating given by most of the people who are dissatisfied or neutral for Arrival and Departure Time convenience: ", dissatisfied_neutral['Departure/Arrival time convenient'].mode()[0])
# Out:
# Rating given by most of the people who are dissatisfied or neutral for Arrival and Departure Time convenience:  4

# %%
print("Median of Flight distance: ", df['Flight Distance'].median())
# Out:
# Median of Flight distance:  843.0

# %%
print("Median of rating for Inflight entertainment is: ", df['Inflight entertainment'].median())
# Out:
# Median of rating for Inflight entertainment is:  4.0

# %%
print("Median of rating for Check-In service is: ", df['Checkin service'].median())
# Out:
# Median of rating for Check-In service is:  3.0

# %% [markdown]
# ###**Encoding**

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder()
df['Gender'] = label_enc.fit_transform(df['Gender'])
df['Customer Type'] = label_enc.fit_transform(df['Customer Type'])
df['Type of Travel'] = label_enc.fit_transform(df['Type of Travel'])
df['Class'] = label_enc.fit_transform(df['Class'])
df['satisfaction'] = label_enc.fit_transform(df['satisfaction'])

# %%
df.head(5)
# Out:
#    Unnamed: 0      id  ...  Arrival Delay in Minutes  satisfaction
# 0           0   70172  ...                      18.0             0
# 1           1    5047  ...                       6.0             0
# 2           2  110028  ...                       0.0             1
# 3           3   24026  ...                       9.0             0
# 4           4  119299  ...                       0.0             1
#
# [5 rows x 25 columns]

# %% [markdown]
# ###**Normalization**

# %%
from sklearn import preprocessing

# %%
minmax_scale = preprocessing.MinMaxScaler().fit(df)
df_minmax = minmax_scale.transform(df)
df_minmax
# Out:
# array([[0.00000000e+00, 5.40279799e-01, 1.00000000e+00, ...,
#         1.57035176e-02, 1.13636364e-02, 0.00000000e+00],
#        [9.62436118e-06, 3.88515464e-02, 1.00000000e+00, ...,
#         6.28140704e-04, 3.78787879e-03, 0.00000000e+00],
#        [1.92487224e-05, 8.47150040e-01, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [9.99980751e-01, 5.29908607e-01, 1.00000000e+00, ...,
#         4.39698492e-03, 8.83838384e-03, 0.00000000e+00],
#        [9.99990376e-01, 4.17095912e-01, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 4.81725298e-01, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ###**Outlier Detection**

# %% [markdown]
# **Detecting Outliers using different methods**

# %% [markdown]
# **a. Using BoxPlot**

# %%
import seaborn as sns
sns.boxplot(df['Flight Distance'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Arrival Delay in Minutes'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **b. Using ScatterPlot**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(11,8))
sns.scatterplot(df['Arrival Delay in Minutes'],df['Departure Delay in Minutes'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(11,8))
plt.scatter(df['Age'], df['Flight Distance'])

# %% [markdown]
# **c. Using Z-score**

# %%
from scipy import stats
import numpy as np
z = abs(stats.zscore(df['Age']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 2023, 19187, 28863, 30723, 31868, 35919, 37138, 37790, 44343,
#        47096, 50799, 58322, 64998, 79872, 81510, 85416, 93821]),)

# %%
z = abs(stats.zscore(df['Inflight wifi service']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
z = abs(stats.zscore(df['Departure/Arrival time convenient']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
z = abs(stats.zscore(df['Ease of Online booking']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
z = abs(stats.zscore(df['Gate location']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
z = abs(stats.zscore(df['Food and drink']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
z = abs(stats.zscore(df['Online boarding']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
z = abs(stats.zscore(df['Seat comfort']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %%
z = abs(stats.zscore(df['Inflight entertainment']))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# **d. IQR**

# %%
Q1 = np.percentile(df['On-board service'], 25)
Q3 = np.percentile(df['On-board service'], 75)
IQR = Q3 - Q1
upper = Q3+1.5*IQR
lower = Q1-1.5*IQR
a = np.array(df.loc[(df['On-board service']<lower) | (df['On-board service']>upper),'Unnamed: 0'])
print(a)
# Out:
# []

# %%
Q1 = np.percentile(df['Leg room service'], 25)
Q3 = np.percentile(df['Leg room service'], 75)
IQR = Q3 - Q1
upper = Q3+1.5*IQR
lower = Q1-1.5*IQR
a = np.array(df.loc[(df['Leg room service']<lower) | (df['Leg room service']>upper),'Unnamed: 0'])
print(a)
# Out:
# []

# %%
Q1 = np.percentile(df['Baggage handling'], 25)
Q3 = np.percentile(df['Baggage handling'], 75)
IQR = Q3 - Q1
upper = Q3+1.5*IQR
lower = Q1-1.5*IQR
a = np.array(df.loc[(df['Baggage handling']<lower) | (df['Baggage handling']>upper),'Unnamed: 0'])
print(a)
# Out:
# []

# %%
Q1 = np.percentile(df['Checkin service'], 25)
Q3 = np.percentile(df['Checkin service'], 75)
IQR = Q3 - Q1
upper = Q3+1.5*IQR
lower = Q1-1.5*IQR
a = np.array(df.loc[(df['Checkin service']<lower) | (df['Checkin service']>upper),'Unnamed: 0'])
print(a)
# Out:
# [     1      3     15 ... 103892 103893 103896]

# %%
Q1 = np.percentile(df['Inflight service'], 25)
Q3 = np.percentile(df['Inflight service'], 75)
IQR = Q3 - Q1
upper = Q3+1.5*IQR
lower = Q1-1.5*IQR
a = np.array(df.loc[(df['Inflight service']<lower) | (df['Inflight service']>upper),'Unnamed: 0'])
print(a)
# Out:
# []

# %%
Q1 = np.percentile(df['Cleanliness'], 25)
Q3 = np.percentile(df['Cleanliness'], 75)
IQR = Q3 - Q1
upper = Q3+1.5*IQR
lower = Q1-1.5*IQR
a = np.array(df.loc[(df['Cleanliness']<lower) | (df['Cleanliness']>upper),'Unnamed: 0'])
print(a)
# Out:
# []

# %% [markdown]
# **Detecting outliers indices for columns which may have outliers using z-score**

# %%
z_age = abs(stats.zscore(df['Age']))
threshold = 3
outliers_Age = np.array(np.where(z > 3))

z_FlightDistance = abs(stats.zscore(df['Flight Distance']))
threshold = 3
outliers_FlightDistance = np.array(np.where(z > 3))

z_DepartureDelay = abs(stats.zscore(df['Departure Delay in Minutes']))
threshold = 3
outliers_DepartureDelay = np.array(np.where(z > 3))

z_ArrivalDelay = abs(stats.zscore(df['Arrival Delay in Minutes']))
threshold = 3
outliers_ArrivalDelay = np.array(np.where(z > 3))

z_CheckInService = abs(stats.zscore(df['Checkin service']))
threshold = 3
outliers_CheckInService = np.array(np.where(z > 3))

# %%
print("Outlier indices in \"Age\": ", outliers_Age)
print("\nOutlier indices in \"Flight Distance\": ", outliers_FlightDistance)
print("\nOutlier indices in \"Departure Delay in Minutes\": ", outliers_DepartureDelay)
print("\nOutlier indices in \"Arrival Delay in Minutes\": ", outliers_ArrivalDelay)
print("\nOutlier indices in \"CheckIn service\": ", outliers_CheckInService)
# Out:
# Outlier indices in "Age":  [[ 2023 19187 28863 30723 31868 35919 37138 37790 44343 47096 50799 58322
#   64998 79872 81510 85416 93821]]
#
# Outlier indices in "Flight Distance":  [[ 2023 19187 28863 30723 31868 35919 37138 37790 44343 47096 50799 58322
#   64998 79872 81510 85416 93821]]
#
# Outlier indices in "Departure Delay in Minutes":  [[ 2023 19187 28863 30723 31868 35919 37138 37790 44343 47096 50799 58322
#   64998 79872 81510 85416 93821]]
#
# Outlier indices in "Arrival Delay in Minutes":  [[ 2023 19187 28863 30723 31868 35919 37138 37790 44343 47096 50799 58322
#   64998 79872 81510 85416 93821]]
#
# Outlier indices in "CheckIn service":  [[ 2023 19187 28863 30723 31868 35919 37138 37790 44343 47096 50799 58322
#   64998 79872 81510 85416 93821]]

# %% [markdown]
# ###**Removing Oultiers**

# %%
outliers_indices = np.unique(np.concatenate([outliers_Age, outliers_FlightDistance, outliers_ArrivalDelay, outliers_DepartureDelay, 
                                             outliers_DepartureDelay], axis = None))
print(outliers_indices)
# Out:
# [ 2023 19187 28863 30723 31868 35919 37138 37790 44343 47096 50799 58322
#  64998 79872 81510 85416 93821]

# %%
print("DataSet shape before removing outliers: ", df.shape)
for index in outliers_indices:
  df.drop(index, inplace=True)
print("DataSet shape after removing outliers: ", df.shape)
# Out:
# DataSet shape before removing outliers:  (103904, 25)
# DataSet shape after removing outliers:  (103887, 25)

# %% [markdown]
# ###**HYPOTHESIS TESTING**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
import scipy.stats as st

# %% [markdown]
# **Finding Confidence Interval for "Age" column taking a sample of 35 with alpha=0.95**

# %%
df_Age_sample = df['Age'].sample(35)

# %%
st.norm.interval(alpha = 0.95, loc = np.mean(df_Age_sample), scale = st.sem(df_Age_sample))
# Out:
# (29.978098134621046, 41.50761615109324)

# %% [markdown]
# **Finding Confidence Interval for "Flight Distance" column taking a sample of 20 for alpha=0.99**

# %%
df_FlightDistance_sample = df['Flight Distance'].sample(20)

# %%
st.t.interval(alpha = 0.99, df = len(df_FlightDistance_sample)-1, loc = np.mean(df_FlightDistance_sample), scale = st.sem(df_FlightDistance_sample))
# Out:
# (824.5306436285222, 2244.0693563714776)

# %% [markdown]
# **Finding Confidence Interval for "Inflight entertainment" column taking sample of 29 for alpha = 0.80**

# %%
df_inflight_ent_sample = df['Inflight entertainment'].sample(29)

# %%
st.t.interval(alpha = 0.80, df = len(df_inflight_ent_sample)-1, loc = np.mean(df_inflight_ent_sample), scale = st.sem(df_inflight_ent_sample))
# Out:
# (2.6876014022257757, 3.3123985962122315)

# %% [markdown]
# **Finding Confidence interval for "Departure Delay in Minutes" taking a sample of 60 with alpha = 0.90**

# %%
df_deprt_Delay_sample = df['Departure Delay in Minutes'].sample(60)

# %%
st.norm.interval(alpha = 0.90, loc = np.mean(df_deprt_Delay_sample), scale = st.sem(df_deprt_Delay_sample))
# Out:
# (7.3258718706577035, 22.94079479600896)

# %% [markdown]
# ###**FEATURE SELECTION**

# %% [markdown]
# ####**Checking for Constant Features and dropping if any**

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(df)
# Out:
# VarianceThreshold(threshold=0)

# %%
constant_columns=[column for column in df.columns if column not in df.columns[var_thres.get_support()]]

# %%
constant_columns
# Out:
# []

# %% [markdown]
# **So there aren't any constant columns i.e., every column in our dataset contributes to the output.Therefore we need not drop any feature from our dataset!!!**

# %% [markdown]
# ####**2. Checking if there are any highly correlated features and dropping them.**

# %%
X = df.drop('satisfaction',axis=1)
y = df['satisfaction']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((72720, 24), (31167, 24), (72720,), (31167,))

# %%
X_train.corr()
# Out:
#                                    Unnamed: 0  ...  Arrival Delay in Minutes
# Unnamed: 0                           1.000000  ...                 -0.001687
# id                                   0.000578  ...                 -0.036804
# Gender                               0.007038  ...                 -0.000835
# Customer Type                       -0.004451  ...                  0.008598
# Age                                  0.007893  ...                 -0.014887
# Type of Travel                      -0.000375  ...                 -0.005341
# Class                               -0.004066  ...                  0.017148
# Flight Distance                      0.001530  ...                 -0.003969
# Inflight wifi service               -0.005361  ...                 -0.020652
# Departure/Arrival time convenient   -0.000982  ...                 -0.003976
# Ease of Online booking               0.001306  ...                 -0.009293
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = X_train.corr()
plt.figure(figsize = (20,15))
sns.heatmap(cor, annot=True, cmap="Blues")
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 2

# %%
corr_features
# Out:
# {'Arrival Delay in Minutes', 'Ease of Online booking'}

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %% [markdown]
# ###**Building ML Models**

# %% [markdown]
# ####**1. Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()

# %%
model_LR.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
y_pred = model_LR.predict(X_test)

# %%
model_LR.score(X_test, y_test)
# Out:
# 0.6952866814258671

# %% [markdown]
# ####**2. Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5, n_estimators=100, oob_score=True)

# %%
# %%time
classifier_rf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# CPU times: user 8.41 s, sys: 28.3 ms, total: 8.44 s
# Wall time: 4.91 s
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
classifier_rf.oob_score_
# Out:
# 0.9159929604575703

# %%
classifier_rf.score(X_test, y_test)
# Out:
# 0.9196394199923008

# %%
rf = RandomForestClassifier(random_state=42, n_jobs=-1)
params = {'max_depth' : [2,3,5,10,20],'min_samples_leaf': [5,10,20,50,100,200],'n_estimators': [10,25,30,50,100,200]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=rf, param_grid=params, cv = 4, n_jobs=-1, verbose=1, scoring="accuracy")

# %%
# %%time
grid_search.fit(X_train, y_train)

# %%
grid_search.best_score_

# %%
rf_best = grid_search.best_estimator_
rf_best

# %%
from sklearn.metrics import confusion_matrix
y_pred = rf_best.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm

# %% [markdown]
# ####**3. Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier(criterion = 'entropy')
X.drop(corr_features, axis = 1, inplace = True)
model_DT.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model_DT.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# **-> INFERENCE**

# %% [markdown]
# So our "DECISION TREE CLASSIFIER" IS GIVING SCORE 1 whereas "LOGISTIC REGRESSION" is giving only 0.69 score. Therefore we can say that Decision Tree Classifier model is perfectly classifying the data

# %% [markdown]
# ###**Models Comparision:**

# %%
from sklearn.metrics import classification_report

# %%
print("\nLOGISTIC REGRESSION:\n")
y_pred_model_LR = model_LR.predict(X_test)
print(classification_report(y_test, y_pred_model_LR))
# Out:
# LOGISTIC REGRESSION:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.69      0.72     17629
#            1       0.64      0.70      0.67     13538
#
#     accuracy                           0.70     31167
#    macro avg       0.69      0.70      0.69     31167
# weighted avg       0.70      0.70      0.70     31167

# %%
print("\nDECISION TREE:\n")
y_pred_model_DT = model_DT.predict(X_test)
print(classification_report(y_test, y_pred_model_DT))
# Out:
# DECISION TREE:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     17629
#            1       1.00      1.00      1.00     13538
#
#     accuracy                           1.00     31167
#    macro avg       1.00      1.00      1.00     31167
# weighted avg       1.00      1.00      1.00     31167
